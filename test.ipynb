# %%
import  pickle
import numpy as np

# %%
(x2,t0) = pickle.load(open("contour_datBig_gradient.pkl","rb"),encoding='latin1')

t0 = t0.squeeze()

# t0 = np.linspace(38,24.5, num=6001)
# x2 = np.linspace(0, 600, num=6001)

# %%
from scipy.stats import expon, norm

X = np.zeros(500)
current_time = 0
approx_time = 0
for i in range(5):
	t = expon.rvs()
	increment = norm.rvs()
	current_time += t
	for j in range(approx_time,int(current_time)):
		pass
# Out:
# array([32.89753523, 32.89656486, 32.89559448, ..., 24.60433162,
#        24.60339819, 24.60246477])

# %%
from BBV_gradient import *
inputVals = np.array([0.725, -0.56, 0.5, 0.39, 0.65, 1.5, 0.75, 0.067])

bbv = BBV_gradient_Richard_taxis(weights=inputVals, p1=0, p2=5)

# %%
bbv.field(360)
# Out:
# nan

# %%
a = 10*inputVals[2]
b = 10*inputVals[3]
bbv.h(1, a, b)
# Out:
# 0.7502601055951175

# %%
import numpy as np
from scipy import signal
import matplotlib.pyplot as plt
t = np.linspace(0, 1, 7)
p = (np.pi)*(1+signal.sawtooth(2 * np.pi * t,  width = 0.5))
print(p[0], p[-1])
plt.plot(t, p)
# Out:
# 0.0 0.0

# %%
mu, sigma = 2, 0.5 # mean and standard deviation
s = np.random.lognormal(mu, sigma, 1000)

import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 100, density=True, align='mid')
x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
       / (x * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()

# %%
mu, sigma = 2, 0.5 # mean and standard deviation
s = np.random.lognormal(mu, sigma, 1000)

import matplotlib.pyplot as plt
count, bins, ignored = plt.hist(s, 100, density=True, align='mid')
x = np.linspace(min(bins), max(bins), 10000)
pdf = (np.exp(-(np.log(x) - mu)**2 / (2 * sigma**2))
       / (x * sigma * np.sqrt(2 * np.pi)))
plt.plot(x, pdf, linewidth=2, color='r')
plt.axis('tight')
plt.show()

# %%
theta = 0
theta0 = 0
thetaG = (130.5)/(180/np.pi)
h = np.linspace(-np.pi, np.pi, num=1000)
PFL = lambda b: np.cos(theta - theta0 - h - b) + 1.5*np.cos(thetaG - theta0 - h) + 2.5
x1 = PFL(67.5/(180/np.pi))
x2 = PFL(-67.5/(180/np.pi))
x3 = PFL(180/(180/np.pi))

# %%
plt.plot(h, x1, label='PFL3R')
plt.plot(h, x2, label='PFL3L')
# plt.plot(h, x3, label='PFL2')
plt.axvline(theta, color='black', label = 'heading')
plt.axvline(thetaG, color='red', label='goal')
plt.legend()
print(np.max(x1)-np.max(x2))
# Out:
# -1.5175993227728113
